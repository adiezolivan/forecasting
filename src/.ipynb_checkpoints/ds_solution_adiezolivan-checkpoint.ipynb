# %% [markdown]
# # NEXTAIL Labs code test

# %%
import pandas as pd
import datetime as dt
import numpy as np
from datetime import datetime,timedelta
import pickle
from sklearn.preprocessing import MinMaxScaler

# %run sales_forecast_methods.py
# %run gru_model.py
# Out:
# Processing available: cpu

# %% [markdown]
# ## Load data

# %%
sales_data = pd.read_csv('../sales_data.csv',parse_dates=['date'])

# %%
from matplotlib import pyplot as plt 
plt.figure(figsize=(24,12))
plt.plot(sales_data.date, sales_data.sales, label='sales')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize=20)
plt.grid()
print(sales_data.shape)
# Out:
# (1462, 2)

# %%
sales_data['sales'].hist()

# %% [markdown]
# ## Set parameters

# %%
order_date = datetime(2020,6,1)
lead_time_days = 90
days_to_next_order = 30
current_stock_level = 400
stock_in_transit = 600

# %% [markdown]
# ## Current solution, mean-based

# %%
def forecast_sales(start_date: datetime, end_date: datetime, sales_data: pd.DataFrame):
    
    days_to_forecast = (end_date - start_date).days
    daily_sales = sales_data[sales_data['date'] < start_date]['sales']
    #daily_sales.hist()
    return daily_sales.mean() * days_to_forecast

# %%
def calculate_new_order (order_date: datetime, lead_time_days: int, days_to_next_order: int, 
                         sales_data: pd.DataFrame, current_stock_level: int, stock_in_transit: int):
    
    arrival_date = order_date + timedelta(days=lead_time_days)
    next_arrival_date = order_date + timedelta(days=days_to_next_order + lead_time_days)
    
    forecast_leadtime = forecast_sales(order_date, arrival_date, sales_data)
    print(forecast_leadtime)
    estimated_stock_at_arrival = current_stock_level - forecast_leadtime + stock_in_transit
    forecast_planning_horizon = forecast_sales(arrival_date, next_arrival_date, sales_data)
    print(forecast_planning_horizon)
    
    order = max(0, forecast_planning_horizon - estimated_stock_at_arrival)
    return order

# %%
sol_mean = calculate_new_order(order_date=order_date, 
                               lead_time_days=lead_time_days, 
                               days_to_next_order=days_to_next_order, 
                               sales_data=sales_data, 
                               current_stock_level=current_stock_level, 
                               stock_in_transit=stock_in_transit)
print(sol_mean)
# Out:
# 889.5277207392197
# 296.5321477428181
# 186.0598684820378

# %% [markdown]
# ### My solution

# %% [markdown]
# # Seasonal, using the information of previous years

# %%
def forecast_sales_seasonal(start_date: datetime, end_date: datetime, sales_data: pd.DataFrame):
    
    #days_to_forecast = (end_date - start_date).days
    # select mean daily sales but for same season
    sales_data['date'] = pd.to_datetime(sales_data['date'], format='%Y%m%d')
    month = start_date.month
    day = start_date.day + 1
    if start_date.day >= 30:
        month += 1
        day = 0
    daily_sales_season = sales_data.loc[(sales_data['date'].dt.year < start_date.year) &
                                        (sales_data['date'].dt.month >= month) &
                                        (sales_data['date'].dt.month <= end_date.month) &
                                        (sales_data['date'].dt.day >= day) &
                                        (sales_data['date'].dt.day <= end_date.day)]
    daily_sales_season.index = daily_sales_season['date']
    daily_sales_season = daily_sales_season.resample('1Y').sum()
    #daily_sales_season.hist()
    
    return np.mean(daily_sales_season.values) # * days_to_forecast


def calculate_new_order_seasonal (order_date: datetime, lead_time_days: int, days_to_next_order: int, 
                                  sales_data: pd.DataFrame, current_stock_level: int, stock_in_transit: int):
    
    arrival_date = order_date + timedelta(days=lead_time_days)
    next_arrival_date = order_date + timedelta(days=days_to_next_order + lead_time_days)
    
    forecast_leadtime = forecast_sales_seasonal(order_date, arrival_date, sales_data)
    print(forecast_leadtime)
    estimated_stock_at_arrival = current_stock_level - forecast_leadtime + stock_in_transit 
    forecast_planning_horizon = forecast_sales_seasonal(arrival_date, next_arrival_date, sales_data)
    print(forecast_planning_horizon)
    
    order = max(0, forecast_planning_horizon - estimated_stock_at_arrival)
    return order

# %%
sol_seasonal = calculate_new_order_seasonal(order_date=order_date, 
                                            lead_time_days=lead_time_days, 
                                            days_to_next_order=days_to_next_order, 
                                            sales_data=sales_data, 
                                            current_stock_level=current_stock_level, 
                                            stock_in_transit=stock_in_transit)
print(sol_seasonal)
# Out:
# 971.0
# 229.75
# 200.75

# %% [markdown]
# # Recurrent solution based on previous trend

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

import torch.optim as optim
from datetime import datetime

seed_all(10)
# Out:
# [ Using Seed :  10  ]

# %%
def forecast_sales_recurrent(start_date: datetime, 
                             end_date: datetime, 
                             sales_data: pd.DataFrame, 
                             verbose: int=1):
    
    days_to_forecast = (end_date - start_date).days
    input_dim = days_to_forecast
    # prepare data with the time lags
    target = sales_data['sales'].values.reshape(-1,1)
    scaler = MinMaxScaler().fit(target)
    target = scaler.transform(target)
    # export current scaler to file for further use
    pickle.dump(scaler, open('scaler_' + str(start_date) + '_' + str(days_to_forecast) + '.p', 'wb'))
    df_generated = generate_time_lags(pd.DataFrame(target, columns=['sales']), input_dim)
    
    val_ratio = 0.2

    X = df_generated.drop('sales', axis=1)
    y = df_generated['sales']
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=val_ratio, shuffle=False)
    
    batch_size = min(30, input_dim)

    train_features = torch.Tensor(X_train.values)
    train_targets = torch.Tensor(y_train.values)
    val_features = torch.Tensor(X_val.values)
    val_targets = torch.Tensor(y_val.values)

    train = TensorDataset(train_features, train_targets)
    val = TensorDataset(val_features, val_targets)

    train_loader = DataLoader(train, batch_size=batch_size, shuffle=False, drop_last=True)
    val_loader = DataLoader(val, batch_size=batch_size, shuffle=False, drop_last=True)
    
    # train the model
    input_dim = len(X_train.columns)
    output_dim = 1
    hidden_dim = 128
    layer_dim = 3
    batch_size = batch_size
    dropout = 0.2
    n_epochs = 100
    learning_rate = 1e-3
    weight_decay = 1e-6

    model_params = {'input_dim': input_dim,
                    'hidden_dim' : hidden_dim,
                    'layer_dim' : layer_dim,
                    'output_dim' : output_dim,
                    'dropout_prob' : dropout}

    model = GRUModel(**model_params)

    loss_fn = nn.MSELoss(reduction="mean")
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

    opt = Optimization(model=model, loss_fn=loss_fn, optimizer=optimizer)
    opt.train(train_loader, 
              val_loader, 
              batch_size=batch_size, 
              n_epochs=n_epochs, 
              n_features=input_dim, 
              model_name='gru_' + str(start_date) + '_' + str(days_to_forecast) + '.pt',
              verbose=verbose)
    #opt.plot_losses()
    
    # make predictions based on previous trend
    d = timedelta(days=days_to_forecast)
    X_test = sales_data[(sales_data['date'] < start_date) &
                        (sales_data['date'] >= start_date-d)]
    if X_test.shape[0] < days_to_forecast:
        year = start_date.year - 1
        X_test = sales_data[(sales_data['date'].dt.year == year)]
        month = (start_date-d).month
        day = (start_date-d).day
        if (start_date-d).day >= 30:
            month += 1
            day = 0
        X_test = X_test[(X_test['date'].dt.month >= month) &
                        (X_test['date'].dt.month <= start_date.month) &
                        (X_test['date'].dt.day >= day) &
                        (X_test['date'].dt.day <= start_date.day)]
    test = np.array(X_test['sales']).reshape(-1,1)
    test = scaler.transform(test)
    
    preds = []
    # prediction step using recurrence
    x_rnn = torch.Tensor(test).squeeze()
    y_hat = x_rnn[-1]
    preds_tmp = []
    for n in range(days_to_forecast):
        if n>0:
            x_rnn = torch.cat((x_rnn[1:], torch.tensor([y_hat]).float()), 0)
        x_test = x_rnn.view([1, -1, input_dim])#.to(device)
        opt.model.eval()
        yhat = opt.model(x_test)
        preds_tmp.append(yhat.cpu().detach().numpy()[0][0])
    preds = np.concatenate((preds, preds_tmp))
    preds = scaler.inverse_transform(np.array(preds).reshape(-1,1)).flatten()
    #plt.figure()
    #plt.hist(preds)
    
    return np.sum(preds) # * days_to_forecast


def calculate_new_order_recurrent (order_date: datetime, 
                                   lead_time_days: int, 
                                   days_to_next_order: int, 
                                   sales_data: pd.DataFrame, 
                                   current_stock_level: int, 
                                   stock_in_transit: int):
    
    arrival_date = order_date + timedelta(days=lead_time_days)
    next_arrival_date = order_date + timedelta(days=days_to_next_order + lead_time_days)
    
    forecast_leadtime = forecast_sales_recurrent(order_date, arrival_date, sales_data)
    print(forecast_leadtime)
    estimated_stock_at_arrival = current_stock_level - forecast_leadtime + stock_in_transit 
    
    forecast_planning_horizon = forecast_sales_recurrent(arrival_date, next_arrival_date, sales_data)
    print(forecast_planning_horizon)
    
    order = max(0,forecast_planning_horizon - estimated_stock_at_arrival)
    return order

# %%
sol_recurrent = calculate_new_order_recurrent(order_date=order_date, 
                                              lead_time_days=lead_time_days, 
                                              days_to_next_order=days_to_next_order, 
                                              sales_data=sales_data, 
                                              current_stock_level=current_stock_level, 
                                              stock_in_transit=stock_in_transit)
print(sol_recurrent)
# Out:
# /home/alberto/anaconda3/lib/python3.7/site-packages/torch/nn/modules/loss.py:446: UserWarning: Using a target size (torch.Size([30, 1])) that is different to the input size (torch.Size([30])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [1/100] Training loss: 0.0320	 Validation loss: 0.0262
# [2/100] Training loss: 0.0274	 Validation loss: 0.0244
# [3/100] Training loss: 0.0266	 Validation loss: 0.0236
# [4/100] Training loss: 0.0262	 Validation loss: 0.0233
# [5/100] Training loss: 0.0261	 Validation loss: 0.0230
# [6/100] Training loss: 0.0259	 Validation loss: 0.0229
# [7/100] Training loss: 0.0258	 Validation loss: 0.0228
# [8/100] Training loss: 0.0257	 Validation loss: 0.0227
# [9/100] Training loss: 0.0257	 Validation loss: 0.0227
# [10/100] Training loss: 0.0257	 Validation loss: 0.0226
# [50/100] Training loss: 0.0253	 Validation loss: 0.0225
# [100/100] Training loss: 0.0256	 Validation loss: 0.0230
# 1117.8259530365467
# /home/alberto/anaconda3/lib/python3.7/site-packages/torch/nn/modules/loss.py:446: UserWarning: Using a target size (torch.Size([30, 1])) that is different to the input size (torch.Size([30])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [1/100] Training loss: 0.0377	 Validation loss: 0.0255
# [2/100] Training loss: 0.0271	 Validation loss: 0.0237
# [3/100] Training loss: 0.0267	 Validation loss: 0.0233
# [4/100] Training loss: 0.0263	 Validation loss: 0.0231
# [5/100] Training loss: 0.0261	 Validation loss: 0.0230
# [6/100] Training loss: 0.0259	 Validation loss: 0.0230
# [7/100] Training loss: 0.0259	 Validation loss: 0.0229
# [8/100] Training loss: 0.0258	 Validation loss: 0.0229
# [9/100] Training loss: 0.0258	 Validation loss: 0.0229
# [10/100] Training loss: 0.0258	 Validation loss: 0.0229
# Early stopping!
# Stopped
# 286.17960610985756
# 404.00555914640427

# %% [markdown]
# # Check resuslts

# %%
manufacturing_cost = 10
selling_price = 25
holding_cost = 0.25 # per Unit and Month  (This is an estimated cost related to the use of the warehouse and the insurance of the stock)
financial_costs = 5 #% TIN (The retailer buys the product using a credit line with that interest)
def compute_gain_vs_cost(order):
    order_cost_manufacturing = order * manufacturing_cost
    order_cost_holding = order * holding_cost * (lead_time_days/30) * 0.85 # dollar to euro
    order_cost_tin = (order_cost_manufacturing + order_cost_holding) * .05 
    order_cost = order_cost_manufacturing + order_cost_holding + order_cost_tin
    order_gain = order * 25
    return order_cost, order_gain

sol_mean_cost, sol_mean_gain = compute_gain_vs_cost(sol_mean)
sol_seasonal_cost, sol_seasonal_gain = compute_gain_vs_cost(sol_seasonal)
sol_recurrent_cost, sol_recurrent_gain = compute_gain_vs_cost(sol_recurrent)

plt.scatter(sol_mean_cost, sol_mean_gain, label='mean')
plt.scatter(sol_seasonal_cost, sol_seasonal_gain, label='seasonal')
plt.scatter(sol_recurrent_cost, sol_recurrent_gain, label='recurrent')
plt.xlabel('gain')
plt.ylabel('cost')
plt.legend()

# %% [markdown]
# ### Check previous years

# %%
real_sales = []
mean_sales = []
seasonal_sales = []
recurrent_sales = []
dates = []
for year in np.unique(sales_data['date'].dt.year)[1:]:
    order_date = datetime(year,6,1)
    lead_time_days = 90
    days_to_next_order = 30
    current_stock_level = 400
    stock_in_transit = 600
    arrival_date = order_date + timedelta(days=lead_time_days)
    next_arrival_date = order_date + timedelta(days=days_to_next_order + lead_time_days)
    dates.append(arrival_date)
    dates.append(next_arrival_date)
    # real sales at arrival
    real_sales_arrival = sales_data.loc[(sales_data['date'].dt.year == order_date.year-1) &
                                        (sales_data['date'].dt.month >= order_date.month) &
                                        (sales_data['date'].dt.month <= arrival_date.month) &
                                        (sales_data['date'].dt.day >= order_date.day) &
                                        (sales_data['date'].dt.day <= arrival_date.day)]
    real_sales_arrival.index = real_sales_arrival['date']
    real_sales_leadtime = real_sales_arrival.resample('1Y').sum()
    real_sales.append(real_sales_leadtime.values[0][0])
    # real sales at next arrival
    month = arrival_date.month
    day = arrival_date.day + 1
    if arrival_date.day >= 30:
        month += 1
        day = 0
    real_sales_next_arrival = sales_data.loc[(sales_data['date'].dt.year == arrival_date.year-1) &
                                             (sales_data['date'].dt.month >= month) &
                                             (sales_data['date'].dt.month <= next_arrival_date.month) &
                                             (sales_data['date'].dt.day >= day) &
                                             (sales_data['date'].dt.day <= next_arrival_date.day)]
    real_sales_next_arrival.index = real_sales_next_arrival['date']
    real_sales_planning_horizon = real_sales_next_arrival.resample('1Y').sum()
    real_sales.append(real_sales_planning_horizon.values[0][0])
    # mean solution
    mean_sales.append(forecast_sales(order_date, arrival_date, sales_data))
    mean_sales.append(forecast_sales(arrival_date, next_arrival_date, sales_data))
    # seasonal solution
    seasonal_sales.append(forecast_sales_seasonal(order_date, arrival_date, sales_data))
    seasonal_sales.append(forecast_sales_seasonal(arrival_date, next_arrival_date, sales_data))
    # recurrent solution
    recurrent_sales.append(forecast_sales_recurrent(order_date, arrival_date, sales_data, verbose=0))
    recurrent_sales.append(forecast_sales_recurrent(arrival_date, next_arrival_date, sales_data, verbose=0))
# Out:
# /home/alberto/anaconda3/lib/python3.7/site-packages/torch/nn/modules/loss.py:446: UserWarning: Using a target size (torch.Size([30, 1])) that is different to the input size (torch.Size([30])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /home/alberto/anaconda3/lib/python3.7/site-packages/torch/nn/modules/loss.py:446: UserWarning: Using a target size (torch.Size([30, 1])) that is different to the input size (torch.Size([30])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Early stopping!
# Stopped
# /home/alberto/anaconda3/lib/python3.7/site-packages/torch/nn/modules/loss.py:446: UserWarning: Using a target size (torch.Size([30, 1])) that is different to the input size (torch.Size([30])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Early stopping!
# Stopped
# /home/alberto/anaconda3/lib/python3.7/site-packages/torch/nn/modules/loss.py:446: UserWarning: Using a target size (torch.Size([30, 1])) that is different to the input size (torch.Size([30])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Early stopping!
# Stopped
# /home/alberto/anaconda3/lib/python3.7/site-packages/torch/nn/modules/loss.py:446: UserWarning: Using a target size (torch.Size([30, 1])) that is different to the input size (torch.Size([30])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Early stopping!
# Stopped
# /home/alberto/anaconda3/lib/python3.7/site-packages/torch/nn/modules/loss.py:446: UserWarning: Using a target size (torch.Size([30, 1])) that is different to the input size (torch.Size([30])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Early stopping!
# Stopped
# /home/alberto/anaconda3/lib/python3.7/site-packages/torch/nn/modules/loss.py:446: UserWarning: Using a target size (torch.Size([30, 1])) that is different to the input size (torch.Size([30])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)

# %% [markdown]
# ### Create table with results achieved for decision support

# %%
# build the dictionary with results achieved
previous_sales = {'real sales': real_sales,
                  'mean solution': mean_sales,
                  'seasonal solution': seasonal_sales,
                  'recurrent solution': recurrent_sales}
ds_table = pd.DataFrame.from_dict(previous_sales)
ds_table.index = dates
ds_table
